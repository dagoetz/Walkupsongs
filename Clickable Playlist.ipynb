# %%
import pandas as pd
import numpy as np
import requests
import warnings
import sys

mlb=pd.read_csv('MLB_Walkup.csv')

# %%
data = mlb
df = pd.DataFrame(data)

def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

df.style.format({'Playlist': make_clickable})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_09e5c2f8_f999_11e8_87ef_8c8590186559" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Team</th>
#         <th class="col_heading level0 col1" >Player</th>
#         <th class="col_heading level0 col2" >Artist</th>
#         <th class="col_heading level0 col3" >Song</th>
#         <th class="col_heading level0 col4" >Playlist</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row0_col0" class="data row0 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row0_col1" class="data row0 col1" >Nick Ahmed</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row0_col2" class="data row0 col2" >TobyMac</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row0_col3" class="data row0 col3" >I just need U.</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row0_col4" class="data row0 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row1_col0" class="data row1 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row1_col1" class="data row1 col1" >Alex Avila</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row1_col2" class="data row1 col2" >The White Stripes</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row1_col3" class="data row1 col3" >Icky Thump</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row1_col4" class="data row1 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row2_col0" class="data row2 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row2_col1" class="data row2 col1" >Brad Boxberger</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row2_col2" class="data row2 col2" >Johnny Cash</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row2_col3" class="data row2 col3" >God's Gonna Cut You Down</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row2_col4" class="data row2 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row3_col0" class="data row3 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row3_col1" class="data row3 col1" >Archie Bradley</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row3_col2" class="data row3 col2" >Jay-Z</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row3_col3" class="data row3 col3" >Public Service Announcement</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row3_col4" class="data row3 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row4_col0" class="data row4 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row4_col1" class="data row4 col1" >Clay Buchholtz</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row4_col2" class="data row4 col2" >Red Rider</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row4_col3" class="data row4 col3" >Lunatic Fringe</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row4_col4" class="data row4 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row5_col0" class="data row5 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row5_col1" class="data row5 col1" >Andrew Chafin</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row5_col2" class="data row5 col2" >Luke Bryan</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row5_col3" class="data row5 col3" >That's My Kind of Night</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row5_col4" class="data row5 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row6_col0" class="data row6 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row6_col1" class="data row6 col1" >Patrick Corbin</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row6_col2" class="data row6 col2" >Matoma & Notorious BIG</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row6_col3" class="data row6 col3" >Old Thing Back</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row6_col4" class="data row6 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row7_col0" class="data row7 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row7_col1" class="data row7 col1" >Socrates Brito</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row7_col2" class="data row7 col2" >Yandel</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row7_col3" class="data row7 col3" >Como Antes (Feat.Wisin)</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row7_col4" class="data row7 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row8_col0" class="data row8 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row8_col1" class="data row8 col1" >Daniel Descalso</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row8_col2" class="data row8 col2" >E-40</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row8_col3" class="data row8 col3" >Tell Me Where To Go</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row8_col4" class="data row8 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_09e5c2f8_f999_11e8_87ef_8c8590186559level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row9_col0" class="data row9 col0" >Diamondbacks</td>
#         <td id="T_09e5c2f8_f999_11e8_87ef_8c8590186559row9_col1" class="data

# %%
mplayer=input("Enter an active MLB player: ")
if mplayer in mlb['Team']:
    #print(df.style.format({'Playlist': make_clickable}).loc['Player'])
    print("The player exists")
else:
    print("The Player does not exist")
# Out:
# Enter an active MLB player: Diamondbacks
# The Player does not exist

# %%
import pandas as pd
import numpy as np
import requests
import warnings
import sys

mlb=pd.read_csv('MLB_Walkup.csv')
mlbplayer=input("Enter an active MLB player: ")

data = mlb
df = pd.DataFrame(data)

def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

df.style.format({'Playlist': make_clickable})



#print(df.loc[df['Player'] == mlbplayer])
# Out:
# Enter an active MLB player: Robbie Ray
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-4cd4022d4317> in <module>
#      20
#      21 #print(df.loc[df['Player'] == mlbplayer])
# ---> 22 print(df.loc[df.style.format({'Playlist': make_clickable})['Player'] == mlbplayer])
#
# TypeError: 'Styler' object is not subscriptable

# %%
mlbplayer=input("Enter an active MLB player: ")
for row in mlb:
    #print(df.style.format({'Playlist': make_clickable}).loc['Player'])
    if row[1]==mlbplayer:
        print(row)
# Out:
# Enter an active MLB player: Robbie Ray

# %%
df.style.format({'Playlist': make_clickable})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_c3f288d8_f997_11e8_9b5a_8c8590186559" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Team</th>
#         <th class="col_heading level0 col1" >Player</th>
#         <th class="col_heading level0 col2" >Artist</th>
#         <th class="col_heading level0 col3" >Song</th>
#         <th class="col_heading level0 col4" >Playlist</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row0_col0" class="data row0 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row0_col1" class="data row0 col1" >Nick Ahmed</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row0_col2" class="data row0 col2" >TobyMac</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row0_col3" class="data row0 col3" >I just need U.</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row0_col4" class="data row0 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row1_col0" class="data row1 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row1_col1" class="data row1 col1" >Alex Avila</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row1_col2" class="data row1 col2" >The White Stripes</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row1_col3" class="data row1 col3" >Icky Thump</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row1_col4" class="data row1 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row2_col0" class="data row2 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row2_col1" class="data row2 col1" >Brad Boxberger</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row2_col2" class="data row2 col2" >Johnny Cash</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row2_col3" class="data row2 col3" >God's Gonna Cut You Down</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row2_col4" class="data row2 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row3_col0" class="data row3 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row3_col1" class="data row3 col1" >Archie Bradley</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row3_col2" class="data row3 col2" >Jay-Z</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row3_col3" class="data row3 col3" >Public Service Announcement</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row3_col4" class="data row3 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row4_col0" class="data row4 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row4_col1" class="data row4 col1" >Clay Buchholtz</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row4_col2" class="data row4 col2" >Red Rider</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row4_col3" class="data row4 col3" >Lunatic Fringe</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row4_col4" class="data row4 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row5_col0" class="data row5 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row5_col1" class="data row5 col1" >Andrew Chafin</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row5_col2" class="data row5 col2" >Luke Bryan</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row5_col3" class="data row5 col3" >That's My Kind of Night</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row5_col4" class="data row5 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row6_col0" class="data row6 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row6_col1" class="data row6 col1" >Patrick Corbin</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row6_col2" class="data row6 col2" >Matoma & Notorious BIG</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row6_col3" class="data row6 col3" >Old Thing Back</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row6_col4" class="data row6 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row7_col0" class="data row7 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row7_col1" class="data row7 col1" >Socrates Brito</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row7_col2" class="data row7 col2" >Yandel</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row7_col3" class="data row7 col3" >Como Antes (Feat.Wisin)</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row7_col4" class="data row7 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row8_col0" class="data row8 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row8_col1" class="data row8 col1" >Daniel Descalso</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row8_col2" class="data row8 col2" >E-40</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row8_col3" class="data row8 col3" >Tell Me Where To Go</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row8_col4" class="data row8 col4" ><a target="_blank" href="https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx">https://open.spotify.com/playlist/7sMUA5x4eURqvVXjM0idGx</a></td>
#     </tr>    <tr>
#         <th id="T_c3f288d8_f997_11e8_9b5a_8c8590186559level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row9_col0" class="data row9 col0" >Diamondbacks</td>
#         <td id="T_c3f288d8_f997_11e8_9b5a_8c8590186559row9_col1" class="data
